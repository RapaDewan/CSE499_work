# %% [markdown]
# <a href="https://colab.research.google.com/github/RapaDewan/CSE499_work/blob/main/CSE499A_Implementation_2/CSE499A_Implementation_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords as stp
from sklearn.feature_extraction.text import CountVectorizer
# nltk.download()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/Resume Ranking Data Set.csv")
df_cp=df.copy()

# %%
df.head()
# Out:
#                              accomplishments_segment             degree  \
# 0                                                NaN  MS , B.TECH , PhD
# 1                                                NaN  B.E , MS , M.TECH
# 2  Successfully cleared and completed the course ...   MS , B.TECH , BS
# 3                                                NaN      B.E , MS , BS
# 4                                                NaN   MS , B.TECH , BS
#
#                                    education_segment  \
# 0                                                NaN
# 1  M.Tech. Data Science\nJSS Science And Technolo...
# 2  Degree\nInstitute\nBoard/University\nYear\nPer...
# 3                                                NaN
# 4                                                NaN
#
#                          emails  \
# 0    sutarvinayak2063@gmail.com
# 1             pooj.vs@gmail.com
# 2  khandelwal.ashwin5@gmail.com
# 3                           NaN
# 4                           NaN
#
#                                           job_titles  \
# 0                     full stack developer , student
# 1                                  software engineer
# 2                                                NaN
# 3  work from home , support analyst , software an...
# 4                        work from home , classifier
#
#                                                links  \
# 0  https://github.com/ramsuthar305/SIH2019 , http...
# 1                                            pooj.vs
# 2  https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                                NaN
# 4  https://github.com/ajay1013/Titanic-ML-from-Di...
#
#                                         misc_segment                  name  \
# 0                                                NaN          Prasad Nagar
# 1  06/2017 – 07/2019\n07/2018 – 07/2019\nmailto:p...     Software Engineer
# 2                                                NaN     Ashwin Khandelwal
# 3                                                NaN  Computer Engineering
# 4                                                NaN             Python
#
#                                   objectives_segment          phone  ...  \
# 0                                                NaN  +919309161108  ...
# 1                                                NaN     7411786822  ...
# 2  I seek challenging environment to work in, tha...     9462710290  ...
# 3                                                NaN   919930485336  ...
# 4                                                NaN   918010295832  ...
#
#                                                 text  \
# 0  VINAYAK \nSUTAR \nLinkedIn  \n+91 9309161108  ...
# 1  POOJA V S\nSoftware Engineer\nRich exposure to...
# 2  Ashwin Khandelwal          \n Email id – khand...
# 3  Assessment\nQ1. Why should you be hired for th...
# 4  Assessment\nQ1. Why should you be hired for th...
#
#                                         university_0  \
# 0                  national, mainpuri, uttar pradesh
# 1                      government, kandhamal, odisha
# 2  narsee monjee institute of management studies,...
# 3                           master, medak, telangana
# 4  greater noida institute of technology, gautam ...
#
#                                         university_1  \
# 0                college of arts, sundargarh, odisha
# 1  vidya vardhaka college of engineering, mysore,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                university_2 university_3 university_4  \
# 0  school of engineering, ernakulam, kerala          NaN          NaN
# 1                                       NaN          NaN          NaN
# 2                                       NaN          NaN          NaN
# 3                                       NaN          NaN          NaN
# 4                                       NaN          NaN          NaN
#
#   university_5                                                url  \
# 0          NaN  https://training-resumes.s3.ap-south-1.amazona...
# 1          NaN  https://training-resumes.s3.ap-south-1.amazona...
# 2          NaN  https://training-resumes.s3.ap-south-1.amazona...
# 3          NaN  https://training-resumes.s3.ap-south-1.amazona...
# 4          NaN  https://training-resumes.s3.ap-south-1.amazona...
#
#   work_experience                                       work_segment
# 0             NaN                                                NaN
# 1             NaN  Merchandising System' using PL/SQL.\nmaintain ...
# 2             NaN  Organization / Institute\nDescription\nBharat ...
# 3             1.0                                                NaN
# 4             NaN                                                NaN
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (1573, 23)

# %% [markdown]
# ##Total null values of each Features

# %%
df.isnull().sum()
# Out:
# accomplishments_segment    1507
# degree                       38
# education_segment          1116
# emails                     1509
# job_titles                   27
# links                       354
# misc_segment               1551
# name                          1
# objectives_segment         1159
# phone                       219
# projects_segment            893
# skills                        0
# skills_segment             1105
# text                          0
# university_0               1007
# university_1               1305
# university_2               1480
# university_3               1545
# university_4               1568
# university_5               1571
# url                           0
# work_experience             854
# work_segment                893
# dtype: int64

# %% [markdown]
# ##Dropping the features which doesn't required

# %%
df.drop(['accomplishments_segment','education_segment','emails','misc_segment','name','objectives_segment','phone','projects_segment','skills_segment','text',
         'university_0','university_1','university_2','university_3','university_4','university_5','url','work_segment'],axis=1,inplace=True)
df.shape
# Out:
# (1573, 5)

# %% [markdown]
# ##Total null values of features after dropping the features

# %%
print('After removing the columns from dataset..')
df.isnull().sum()
# Out:
# After removing the columns from dataset..
# degree              38
# job_titles          27
# links              354
# skills               0
# work_experience    854
# dtype: int64

# %% [markdown]
# ##Handling null values of features

# %%
df['degree'].fillna(df.degree.mode()[0],inplace=True)
df['links'].fillna('Missing',inplace=True)
df['work_experience'].fillna(0,inplace=True)
df['job_titles'].fillna('No Job',inplace=True)
# Out:
# <ipython-input-15-cd0d7b3103da>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['degree'].fillna(df.degree.mode()[0],inplace=True)
# <ipython-input-15-cd0d7b3103da>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['links'].fillna('Missing',inplace=True)
# <ipython-input-15-cd0d7b3103da>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['work_experience'].fillna(0,inplace=True)
# <ipython-input-15-cd0d7b3103da>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['job_titles'].fillna('No Job',inplace=True)

# %% [markdown]
# ##Fetching the unique value from the 'degree' feature

# %%
df.head()
# Out:
#               degree                                         job_titles  \
# 0  MS , B.TECH , PhD                     full stack developer , student
# 1  B.E , MS , M.TECH                                  software engineer
# 2   MS , B.TECH , BS                                             No Job
# 3      B.E , MS , BS  work from home , support analyst , software an...
# 4   MS , B.TECH , BS                        work from home , classifier
#
#                                                links  \
# 0  https://github.com/ramsuthar305/SIH2019 , http...
# 1                                            pooj.vs
# 2  https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                            Missing
# 4  https://github.com/ajay1013/Titanic-ML-from-Di...
#
#                                               skills  work_experience
# 0  algorithms , interview , visualisation , robot...              0.0
# 1  core java , algorithms , sql tools , deep lear...              0.0
# 2  digital signal processing , algorithms , capac...              0.0
# 3  big data analytics , award , training , comput...              1.0
# 4  functionality , algorithms , spark , data visu...              0.0

# %%
all_degrees = ''
for i in df.degree:
  if len(all_degrees) == 0:
    all_degrees = i
  else:
    all_degrees = all_degrees + ' , ' + i

all_degrees = all_degrees.split(',')
all_degrees = [re.sub("[\s.]","",i).upper() for i in all_degrees]
unique_degrees = set(all_degrees)
unique_degrees
# Out:
# {'BE', 'BS', 'BSC', 'BTECH', 'ME', 'MS', 'MSC', 'MTECH', 'PHD'}

# %% [markdown]
# ##Feature Handling of 'degree', 'links' and 'work_experience'

# %%
df['bachelor_degrees'] = 'No Degree'
df['master_degrees'] = 'No Degree'
df['docterte_degrees'] = 'No Degree'
df['profiles'] = 'No Profile'

# %%
df.head()
# Out:
#               degree                                         job_titles  \
# 0  MS , B.TECH , PhD                     full stack developer , student
# 1  B.E , MS , M.TECH                                  software engineer
# 2   MS , B.TECH , BS                                             No Job
# 3      B.E , MS , BS  work from home , support analyst , software an...
# 4   MS , B.TECH , BS                        work from home , classifier
#
#                                                links  \
# 0  https://github.com/ramsuthar305/SIH2019 , http...
# 1                                            pooj.vs
# 2  https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                            Missing
# 4  https://github.com/ajay1013/Titanic-ML-from-Di...
#
#                                               skills  work_experience  \
# 0  algorithms , interview , visualisation , robot...              0.0
# 1  core java , algorithms , sql tools , deep lear...              0.0
# 2  digital signal processing , algorithms , capac...              0.0
# 3  big data analytics , award , training , comput...              1.0
# 4  functionality , algorithms , spark , data visu...              0.0
#
#   bachelor_degrees master_degrees docterte_degrees    profiles
# 0        No Degree      No Degree        No Degree  No Profile
# 1        No Degree      No Degree        No Degree  No Profile
# 2        No Degree      No Degree        No Degree  No Profile
# 3        No Degree      No Degree        No Degree  No Profile
# 4        No Degree      No Degree        No Degree  No Profile

# %% [markdown]
# ##1. 'degree' convert into 'bachelor', 'master', and 'docterte'

# %%
ind = 0
for i in df.degree:
  lst = re.sub("[\s.]","",i).upper( )
  # print(lst)
  for j in lst.split(','):
    if j in ['BE', 'BS', 'BSC', 'BTECH']:
      if df.loc[ind,'bachelor_degrees'] == 'No Degree':
        df.loc[ind,'bachelor_degrees'] = j
      else:
        df.loc[ind,'bachelor_degrees'] = df.loc[ind,'bachelor_degrees'] + ' , '+ j
    elif j in ['ME', 'MS', 'MSC', 'MTECH']:
      if df.loc[ind,'master_degrees'] == 'No Degree':
        df.loc[ind,'master_degrees'] = j
      else:
        df.loc[ind,'master_degrees'] = df.loc[ind,'master_degrees'] + ' , '+ j
    elif j == 'PHD':
      if df.loc[ind,'docterte_degrees'] == 'No Degree':
        df.loc[ind,'docterte_degrees'] = j
      else:
        df.loc[ind,'docterte_degrees'] = df.loc[ind,'docterte_degrees'] + ' , '+ j
  ind +=1

# %%
df.head()
# Out:
#               degree                                         job_titles  \
# 0  MS , B.TECH , PhD                     full stack developer , student
# 1  B.E , MS , M.TECH                                  software engineer
# 2   MS , B.TECH , BS                                             No Job
# 3      B.E , MS , BS  work from home , support analyst , software an...
# 4   MS , B.TECH , BS                        work from home , classifier
#
#                                                links  \
# 0  https://github.com/ramsuthar305/SIH2019 , http...
# 1                                            pooj.vs
# 2  https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                            Missing
# 4  https://github.com/ajay1013/Titanic-ML-from-Di...
#
#                                               skills  work_experience  \
# 0  algorithms , interview , visualisation , robot...              0.0
# 1  core java , algorithms , sql tools , deep lear...              0.0
# 2  digital signal processing , algorithms , capac...              0.0
# 3  big data analytics , award , training , comput...              1.0
# 4  functionality , algorithms , spark , data visu...              0.0
#
#   bachelor_degrees master_degrees docterte_degrees    profiles
# 0            BTECH             MS              PHD  No Profile
# 1               BE     MS , MTECH        No Degree  No Profile
# 2       BTECH , BS             MS        No Degree  No Profile
# 3          BE , BS             MS        No Degree  No Profile
# 4       BTECH , BS             MS        No Degree  No Profile

# %% [markdown]
# ##2. 'links' convert into 'profile'

# %%
ind = 0
for i in df.links:
  lst = re.sub("[\s]","",i)
  # print(lst)
  for j in lst.split(','):
    if j.find('github') != -1:
      df.loc[ind,'profiles'] = 'Github'
    elif j.find('linkedin') != -1:
      if df.loc[ind,'profiles'] == 'No Profile':
        df.loc[ind,'profiles'] = 'Linkedin'
      else:
        df.loc[ind,'profiles'] = df.loc[ind,'profiles'] + ' , ' + 'Linkedin'
  ind +=1

# %%
df
# Out:
#                           degree  \
# 0              MS , B.TECH , PhD
# 1              B.E , MS , M.TECH
# 2               MS , B.TECH , BS
# 3                  B.E , MS , BS
# 4               MS , B.TECH , BS
# ...                          ...
# 1568           B.E , MS , M.TECH
# 1569                     MS , BS
# 1570  B.S , M.Sc , M.S , BS , MS
# 1571                          MS
# 1572                          BS
#
#                                              job_titles  \
# 0                        full stack developer , student
# 1                                     software engineer
# 2                                                No Job
# 3     work from home , support analyst , software an...
# 4                           work from home , classifier
# ...                                                 ...
# 1568  branch manager , embedded software developer ,...
# 1569      devops , senior android developer , team lead
# 1570  devops engineer , traffic manager , release ma...
# 1571                                         classifier
# 1572                                             No Job
#
#                                                   links  \
# 0     https://github.com/ramsuthar305/SIH2019 , http...
# 1                                               pooj.vs
# 2     https://www.linkedin.com/in/ashwin-khandelwal-...
# 3                                               Missing
# 4     https://github.com/ajay1013/Titanic-ML-from-Di...
# ...                                                 ...
# 1568  https://www.linkedin.com/in , https://grv20.gi...
# 1569  com.gokada , https://play.google.com/store/app...
# 1570  https://freesearch.naukri.com/preview/printResume
# 1571                                            Missing
# 1572                 https://github.com/YashshreeShinde
#
#                                                  skills  work_experience  \
# 0     algorithms , interview , visualisation , robot...              0.0
# 1     core java , algorithms , sql tools , deep lear...              0.0
# 2     digital signal processing , algorithms , capac...              0.0
# 3     big data analytics , award , training , comput...              1.0
# 4     functionality , algorithms , spark , data visu...              0.0
# ...                                                 ...              ...
# 1568  digital communication , api , atom , robot , c...              2.0
# 1569  reporting , functionality , socket.io , mockit...              2.0
# 1570  version control , renewals , nfs , telugu , vi...             12.0
# 1571  natural language , matplotlib , boost , custom...              0.0
# 1572  employability , python , github , javascript ,...              0.0
#
#      bachelor_degrees master_degrees docterte_degrees           profiles
# 0               BTECH             MS              PHD             Github
# 1                  BE     MS , MTECH        No Degree         No Profile
# 2          BTECH , BS             MS        No Degree           Linkedin
# 3             BE , BS             MS        No Degree         No Profile
# 4          BTECH , BS             MS        No Degree             Github
# ...               ...            ...              ...                ...
# 1568               BE     MS , MTECH        No Degree  Github , Linkedin
# 1569               BS             MS        No Degree         No Profile
# 1570          BS , BS  MSC , MS , MS        No Degree         No Profile
# 1571        No Degree             MS        No Degree         No Profile
# 1572               BS      No Degree        No Degree             Github
#
# [1573 rows x 9 columns]

# %% [markdown]
# ##3. handling the null values of work_experience and converted it's all data into integer format

# %%
# list(df['work_experience'].unique())
df.work_experience.value_counts()
# Out:
# work_experience
#  0.0       854
#  4.0       151
#  2.0        91
#  1.0        87
#  3.0        81
#  5.0        73
#  6.0        52
#  8.0        34
#  7.0        32
#  9.0        23
#  14.0       14
#  11.0       12
#  10.0       12
#  12.0       11
#  13.0        6
#  18.0        5
#  15.0        4
#  17.0        4
#  21.0        4
#  22.0        2
#  2005.0      2
#  2004.0      2
#  16.0        2
#  2003.0      2
#  2006.0      2
#  20.0        2
#  2002.0      1
#  2010.0      1
#  2001.0      1
#  2012.0      1
# -3.0         1
#  1999.0      1
#  2013.0      1
#  2008.0      1
#  19.0        1
# Name: count, dtype: int64

# %%
ind = 0
for i in df.work_experience:
  if i < 0:
    df.loc[ind,'work_experience'] = i*-1
  elif i > 40:
    df.loc[ind,'work_experience'] = 0
  ind +=1
df['work_experience'] = df['work_experience'].astype(int)

# %% [markdown]
# ##Removing the 'degree' and 'links' from the dataset after feature handling

# %%
df.drop(['degree','links'],axis=1,inplace=True)

# %%
df
# Out:
#                                              job_titles  \
# 0                        full stack developer , student
# 1                                     software engineer
# 2                                                No Job
# 3     work from home , support analyst , software an...
# 4                           work from home , classifier
# ...                                                 ...
# 1568  branch manager , embedded software developer ,...
# 1569      devops , senior android developer , team lead
# 1570  devops engineer , traffic manager , release ma...
# 1571                                         classifier
# 1572                                             No Job
#
#                                                  skills  work_experience  \
# 0     algorithms , interview , visualisation , robot...                0
# 1     core java , algorithms , sql tools , deep lear...                0
# 2     digital signal processing , algorithms , capac...                0
# 3     big data analytics , award , training , comput...                1
# 4     functionality , algorithms , spark , data visu...                0
# ...                                                 ...              ...
# 1568  digital communication , api , atom , robot , c...                2
# 1569  reporting , functionality , socket.io , mockit...                2
# 1570  version control , renewals , nfs , telugu , vi...               12
# 1571  natural language , matplotlib , boost , custom...                0
# 1572  employability , python , github , javascript ,...                0
#
#      bachelor_degrees master_degrees docterte_degrees           profiles
# 0               BTECH             MS              PHD             Github
# 1                  BE     MS , MTECH        No Degree         No Profile
# 2          BTECH , BS             MS        No Degree           Linkedin
# 3             BE , BS             MS        No Degree         No Profile
# 4          BTECH , BS             MS        No Degree             Github
# ...               ...            ...              ...                ...
# 1568               BE     MS , MTECH        No Degree  Github , Linkedin
# 1569               BS             MS        No Degree         No Profile
# 1570          BS , BS  MSC , MS , MS        No Degree         No Profile
# 1571        No Degree             MS        No Degree         No Profile
# 1572               BS      No Degree        No Degree             Github
#
# [1573 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# job_titles          0
# skills              0
# work_experience     0
# bachelor_degrees    0
# master_degrees      0
# docterte_degrees    0
# profiles            0
# dtype: int64

# %%
df
# Out:
#                                              job_titles  \
# 0                        full stack developer , student
# 1                                     software engineer
# 2                                                No Job
# 3     work from home , support analyst , software an...
# 4                           work from home , classifier
# ...                                                 ...
# 1568  branch manager , embedded software developer ,...
# 1569      devops , senior android developer , team lead
# 1570  devops engineer , traffic manager , release ma...
# 1571                                         classifier
# 1572                                             No Job
#
#                                                  skills  work_experience  \
# 0     algorithms , interview , visualisation , robot...                0
# 1     core java , algorithms , sql tools , deep lear...                0
# 2     digital signal processing , algorithms , capac...                0
# 3     big data analytics , award , training , comput...                1
# 4     functionality , algorithms , spark , data visu...                0
# ...                                                 ...              ...
# 1568  digital communication , api , atom , robot , c...                2
# 1569  reporting , functionality , socket.io , mockit...                2
# 1570  version control , renewals , nfs , telugu , vi...               12
# 1571  natural language , matplotlib , boost , custom...                0
# 1572  employability , python , github , javascript ,...                0
#
#      bachelor_degrees master_degrees docterte_degrees           profiles
# 0               BTECH             MS              PHD             Github
# 1                  BE     MS , MTECH        No Degree         No Profile
# 2          BTECH , BS             MS        No Degree           Linkedin
# 3             BE , BS             MS        No Degree         No Profile
# 4          BTECH , BS             MS        No Degree             Github
# ...               ...            ...              ...                ...
# 1568               BE     MS , MTECH        No Degree  Github , Linkedin
# 1569               BS             MS        No Degree         No Profile
# 1570          BS , BS  MSC , MS , MS        No Degree         No Profile
# 1571        No Degree             MS        No Degree         No Profile
# 1572               BS      No Degree        No Degree             Github
#
# [1573 rows x 7 columns]

# %% [markdown]
# ##Defining the functions to calculate the rank of the resume

# %%
lemmatizer = WordNetLemmatizer()
analyzer = CountVectorizer().build_analyzer()

def stemmed_words(doc):
    return (lemmatizer.lemmatize(w,get_wordnet_pos(w)) for w in analyzer(doc) if w not in set(stp.words('english')))

# %%
def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)

# %%
def get_tf_idf_cosine_similarity(job_desc,all_resumes):
    tf_idf_vect = TfidfVectorizer(analyzer=stemmed_words)
    tf_idf_desc_vector = tf_idf_vect.fit_transform([job_desc]).todense()
    tf_idf_resume_vector = tf_idf_vect.transform(all_resumes).todense()
    cosine_similarity_list = []
    for i in range(len(tf_idf_resume_vector)):
        cosine_similarity_list.append(cosine_similarity(tf_idf_desc_vector,tf_idf_resume_vector[i])[0][0])
    return cosine_similarity_list

# %% [markdown]
# ##Opening the Job Description from the text file

# %%
with open('/content/drive/MyDrive/Job Description.txt','r',encoding = 'utf-8') as f:
  file_desc_lst =  [r.replace('\n', '') for r in f.readlines()]

# %%
job_description = ''

for i in file_desc_lst:
  if len(job_description) == 0:
    job_description = str(i)
  else:
    job_description = job_description + ' ' + str(i)

# %% [markdown]
# ##Reading all resume's from the dataset and convert into text which will appended into a list

# %%
all_resume_text = []

for i in df.iloc[:].values:
  s = ''
  for j in list(i):
    if len(s) == 0:
      s = str(j)
    else:
      s = s + ' , ' + str(j)
  all_resume_text.append(s)

# %% [markdown]
# ##Call 'get_tf_idf_cosine_similarity' function which will give us the cosine score

# %%
import nltk
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')  # Corrected resource name

# Your existing code
cos_sim_list = get_tf_idf_cosine_similarity(job_description, all_resume_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-42-28e223bfe9cf> in <cell line: 6>()
#       4
#       5 # Your existing code
# ----> 6 cos_sim_list = get_tf_idf_cosine_similarity(job_description, all_resume_text)
#
# <ipython-input-32-15aea8aa80cc> in get_tf_idf_cosine_similarity(job_desc, all_resumes)
#       1 def get_tf_idf_cosine_similarity(job_desc,all_resumes):
#       2     tf_idf_vect = TfidfVectorizer(analyzer=stemmed_words)
# ----> 3     tf_idf_desc_vector = tf_idf_vect.fit_transform([job_desc]).todense()
#       4     tf_idf_resume_vector = tf_idf_vect.transform(all_resumes).todense()
#       5     cosine_similarity_list = []
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    2089             sublinear_tf=self.sublinear_tf,
#    2090         )
# -> 2091         X = super().fit_transform(raw_documents)
#    2092         self._tfidf.fit(X)
#    2093         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1370                     break
#    1371
# -> 1372         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1373
#    1374         if self.binary:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1257         for doc in raw_documents:
#    1258             feature_counter = {}
# -> 1259             for feature in analyze(doc):
#    1260                 try:
#    1261                     feature_idx = vocabulary[feature]
#
# <ipython-input-30-f9248708a8a5> in <genexpr>(.0)
#       3
#       4 def stemmed_words(doc):
# ----> 5     return (lemmatizer.lemmatize(w,get_wordnet_pos(w)) for w in analyzer(doc) if w not in set(stp.words('english')))
#       6
#
# <ipython-input-31-a71f72a7a8ef> in get_wordnet_pos(word)
#       1 def get_wordnet_pos(word):
# ----> 2     tag = nltk.pos_tag([word])[0][1][0].upper()
#       3     tag_dict = {"J": wordnet.ADJ,
#       4                 "N": wordnet.NOUN,
#       5                 "V": wordnet.VERB,
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#     170
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/__init__.py in _get_tagger(lang)
#     108         tagger = PerceptronTagger(lang=lang)
#     109     else:
# --> 110         tagger = PerceptronTagger()
#     111     return tagger
#     112
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/perceptron.py in __init__(self, load, lang)
#     181         self.classes = set()
#     182         if load:
# --> 183             self.load_from_json(lang)
#     184
#     185     def tag(self, tokens, return_conf=False, use_tagdict=True):
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/perceptron.py in load_from_json(self, lang)
#     271     def load_from_json(self, lang="eng"):
#     272         # Automatically find path to the tagger if location is not specified.
# --> 273         loc = find(f"taggers/averaged_perceptron_tagger_{lang}/")
#     274         with open(loc + TAGGER_JSONS[lang]["weights"]) as fin:
#     275             self.model.weights = json.load(fin)
#
# /usr/local/lib/python3.10/dist-packages/nltk/data.py in find(resource_name, paths)
#     577     sep = "*" * 70
#     578     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579     raise LookupError(resource_not_found)
#     580
#     581
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger_eng not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger_eng/
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
cos_sim_list = get_tf_idf_cosine_similarity(job_description,all_resume_text)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-41-f479f0f62513> in <cell line: 1>()
# ----> 1 cos_sim_list = get_tf_idf_cosine_similarity(job_description,all_resume_text)
#
# <ipython-input-32-15aea8aa80cc> in get_tf_idf_cosine_similarity(job_desc, all_resumes)
#       1 def get_tf_idf_cosine_similarity(job_desc,all_resumes):
#       2     tf_idf_vect = TfidfVectorizer(analyzer=stemmed_words)
# ----> 3     tf_idf_desc_vector = tf_idf_vect.fit_transform([job_desc]).todense()
#       4     tf_idf_resume_vector = tf_idf_vect.transform(all_resumes).todense()
#       5     cosine_similarity_list = []
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    2089             sublinear_tf=self.sublinear_tf,
#    2090         )
# -> 2091         X = super().fit_transform(raw_documents)
#    2092         self._tfidf.fit(X)
#    2093         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1370                     break
#    1371
# -> 1372         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1373
#    1374         if self.binary:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1257         for doc in raw_documents:
#    1258             feature_counter = {}
# -> 1259             for feature in analyze(doc):
#    1260                 try:
#    1261                     feature_idx = vocabulary[feature]
#
# <ipython-input-30-f9248708a8a5> in <genexpr>(.0)
#       3
#       4 def stemmed_words(doc):
# ----> 5     return (lemmatizer.lemmatize(w,get_wordnet_pos(w)) for w in analyzer(doc) if w not in set(stp.words('english')))
#       6
#
# <ipython-input-31-a71f72a7a8ef> in get_wordnet_pos(word)
#       1 def get_wordnet_pos(word):
# ----> 2     tag = nltk.pos_tag([word])[0][1][0].upper()
#       3     tag_dict = {"J": wordnet.ADJ,
#       4                 "N": wordnet.NOUN,
#       5                 "V": wordnet.VERB,
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     166     :rtype: list(tuple(str, str))
#     167     """
# --> 168     tagger = _get_tagger(lang)
#     169     return _pos_tag(tokens, tagset, tagger, lang)
#     170
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/__init__.py in _get_tagger(lang)
#     108         tagger = PerceptronTagger(lang=lang)
#     109     else:
# --> 110         tagger = PerceptronTagger()
#     111     return tagger
#     112
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/perceptron.py in __init__(self, load, lang)
#     181         self.classes = set()
#     182         if load:
# --> 183             self.load_from_json(lang)
#     184
#     185     def tag(self, tokens, return_conf=False, use_tagdict=True):
#
# /usr/local/lib/python3.10/dist-packages/nltk/tag/perceptron.py in load_from_json(self, lang)
#     271     def load_from_json(self, lang="eng"):
#     272         # Automatically find path to the tagger if location is not specified.
# --> 273         loc = find(f"taggers/averaged_perceptron_tagger_{lang}/")
#     274         with open(loc + TAGGER_JSONS[lang]["weights"]) as fin:
#     275             self.model.weights = json.load(fin)
#
# /usr/local/lib/python3.10/dist-packages/nltk/data.py in find(resource_name, paths)
#     577     sep = "*" * 70
#     578     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579     raise LookupError(resource_not_found)
#     580
#     581
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger_eng not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger_eng')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger_eng/
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
zipped_resume_rating = zip(cos_sim_list,df_cp.name,[x for x in range(len(df))])
sorted_resume_rating_list = sorted(zipped_resume_rating, key = lambda x: x[0], reverse=True)

# %%
resume_score = [round(x*100,2) for x in cos_sim_list]
pd.concat([df_cp.name,pd.DataFrame(resume_score,columns=['resume_score(%)'])],axis=1).sort_values(by=['resume_score(%)'],ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-2c9153fce12a> in <cell line: 1>()
# ----> 1 resume_score = [round(x*100,2) for x in cos_sim_list]
#       2 pd.concat([df_cp.name,pd.DataFrame(resume_score,columns=['resume_score(%)'])],axis=1).sort_values(by=['resume_score(%)'],ascending=False).head(10)
#       3
#
# NameError: name 'cos_sim_list' is not defined
